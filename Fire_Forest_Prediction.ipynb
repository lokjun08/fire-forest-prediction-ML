# %%
import pandas as pd

# %%
df= pd.read_csv("Forest_Fires_Dataset__1881-2025_.csv")

# %%
print(df.head())
print(df.info())
# Out:
#   Country  Year    Month     Region  Fires_Count  Burned_Area_Ha  \
# 0  Turkey  1881   August      Mugla          353           76920
# 1  Turkey  1881     July    Antalya          154           64920
# 2  Turkey  1881     June      Izmir          196           83204
# 3   Spain  1881     July  Catalonia           63           84578
# 4   Spain  1881  October  Andalusia          450           84754
#
#            Cause  Temperature_C  Humidity_Percent  Wind_Speed_kmh
# 0      Lightning             33                91              25
# 1      Lightning             38                34              39
# 2        Unknown             36                93              50
# 3      Lightning             42                64              16
# 4  Deforestation             17                55               8
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4060 entries, 0 to 4059
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ...

# %%
print("Hi")
# Out:
# Hi
